# %% [markdown]
# # Python_Lab_2.2

# %% [markdown]
# ### Task 1
# 1. Write a program that prompts the user to enter two numbers and prints their division. Handle cases where the user enters non-numeric values or attempts to divide by zero using a try-except block.

# %%
try:
    # Prompt the user to enter the numbers
    num1 = input("Enter a number: ")
    num2 = input("Enter another number: ")

    # Attempt to divide the two numbers and print the result
    print(f"The division of {num1} by {num2} is {float(num1) / float(num2)}")
    
except ZeroDivisionError:
    # Handle the case where the second number is zero
    print("You can't divide by zero!")
except ValueError:
    # Handle the case where the user entered a non-numeric value
    print("Please enter a valid number!")
# Out:
# The division of 2 by 6 is 0.3333333333333333

# %% [markdown]
# ### Task 2
# - Use "Random" library to do the following:
#     1. Create a list of random numbers using list comprehension.
#     2. Create a list of squares of the even numbers from random numbers using list comprehension.
#     3. Create a list of tuples (number, square) for random numbers using list comprehension.

# %%
import random

# Create a list of random numbers using list comprehension
random_numbers = [random.randint(0, 50) for _ in range(10)]
print("Random Numbers:", random_numbers)

# Create a list of squares of the even numbers from random numbers using list comprehension
even_squares = [num ** 2 for num in random_numbers if num % 2 == 0]
print("Squares of Even Numbers:", even_squares)

# Create a list of tuples (number, square) for random numbers using list comprehension
number_square_tuples = [(num, num ** 2) for num in random_numbers]
print("Tuples of (Number, Square):", number_square_tuples)
# Out:
# Random Numbers: [49, 24, 32, 7, 5, 16, 38, 24, 50, 38]
# Squares of Even Numbers: [576, 1024, 256, 1444, 576, 2500, 1444]
# Tuples of (Number, Square): [(49, 2401), (24, 576), (32, 1024), (7, 49), (5, 25), (16, 256), (38, 1444), (24, 576), (50, 2500), (38, 1444)]

# %% [markdown]
# ### Task 3
# - Create a dictionary where the keys are numbers from 1 to 5 and the values are list of their squares and cubes.
#
#   - **hint**: use dictionary of list comprehension.
#
# - Create a dictionary from two lists (one with keys and one with values) using dictionary comprehension.

# %%
# Create a dictionary where the keys are numbers from 1 to 5 and the values are lists of their squares and cubes
squares_cubes = {num: [num**2, num**3] for num in range(1, 6)}
print("Squares and Cubes:", squares_cubes)

# Create a dictionary from two lists (keys and values) using dictionary comprehension
keys = ['a', 'b', 'c']
values = [1, 2, 3]
dictionary = {key: value for key, value in zip(keys, values)}
print("Dictionary:", dictionary)
# Out:
# Squares and Cubes: {1: [1, 1], 2: [4, 8], 3: [9, 27], 4: [16, 64], 5: [25, 125]}
# Dictionary: {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ### Task 4
# - Given a dictionary where keys are student names and values are lists of their scores, write a function that updates the scores of students who have achieved a perfect score (100) by adding a bonus of 5 points to each score. Use dictionary comprehension to achieve this.
#
#     - Implement the function add_bonus_to_perfect_scores(student_scores) that adds a bonus of 5 points to each score of students who have achieved a perfect score (100).

# %%
def add_bonus_to_perfect_scores(student_scores):
    # Using dictionary comprehension to update scores
    update_scores = {
        name: [score + 5 if score == 100 else score for score in student_scores]
        for name, student_scores in student_scores.items()
    }
    return update_scores

# Define a dictionary with student names as keys and their scores as values
student_scores = {
    "Ahmed": [90, 100, 85],
    "Khalid": [100, 75, 100],
    "Rakan": [80, 70, 60],
}

# Call the function to add bonus points to perfect scores
updated_student_scores = add_bonus_to_perfect_scores(student_scores)

# Print the updated student scores
print("Updated Student Scores:", updated_student_scores)
# Out:
# Updated Student Scores: {'Alice': [90, 105, 85], 'Bob': [105, 75, 105], 'Charlie': [80, 70, 60], 'David': [105, 105, 105]}
